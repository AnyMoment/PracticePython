# %% [markdown]
# ### Question 1:Import the customer data into python.

# %%
import pandas as pd
CustomerData=pd.read_csv('C:/Users/xskolantaa/Desktop/Customers.csv')
#print (CustomerData)

# %% [markdown]
# ### Q2:Understand the data using different functions and attributes like shape, index, columns, dtypes.ndim, info(), get_dtype_counts etc

# %%
#Head 
CustomerData.head

# %%
CustomerData.shape #denotes rows,columns
# Out:
# (10000, 14)

# %%
CustomerData.index #index of the dataset
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
CustomerData.columns #Number of columns
# Out:
# Index(['Customer_ID', 'Gender', 'First_Date', 'First_region', 'First_state',
#        'First_city', 'Recent_Date', 'Last_region', 'Last_state', 'Last_city',
#        'Customer_Value', 'Buy_Times', 'Points_Earned', 'Points_Redeemed'],
#       dtype='object')

# %%
CustomerData.ndim #number of dimensions in DataFrame
# Out:
# 2

# %%
CustomerData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Customer_ID        10000 non-null int64
# Gender             9986 non-null object
# First_Date         10000 non-null int64
# First_region       9979 non-null object
# First_state        9983 non-null object
# First_city         10000 non-null object
# Recent_Date        10000 non-null int64
# Last_region        10000 non-null object
# Last_state         10000 non-null object
# Last_city          10000 non-null object
# Customer_Value     9964 non-null float64
# Buy_Times          10000 non-null int64
# Points_Earned      9979 non-null float64
# Points_Redeemed    9988 non-null float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
CustomerData.get_dtype_counts()
# Out:
# float64    3
# int64      4
# object     7
# dtype: int64

# %% [markdown]
# ### Q3: What is percentage of missing values for customer Value variable

# %%
missingData=CustomerData.isna()
missingData_mis=missingData.sum()
perce= missingData_mis/len(CustomerData)*100
print(perce.get('Customer_Value'))
# Out:
# 0.36

# %% [markdown]
# ### Q4:Create two subsets with unique and duplicate values

# %%
UniqSet= CustomerData.drop_duplicates(keep=False,inplace=False)
UniqSet
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 0       129609144      M    20130130         West         Gujarat
# 1       129627580      M    20130129        North           Delhi
# 2       130363481      M    20130221         West         Gujarat
# 3        49817480      M    20130222         West     Maharashtra
# 4       126343829      F    20130301        North           Delhi
# 5         8223758      F    20130314         West         Gujarat
# 6       131816709      M    20130318        South  Andhra Pradesh
# 7       118543320      F    20130321        North   Uttar Pradesh
# 8       131365512      M    20130323         East     West Bengal
# 9          758571      M    20130324        South       Karnataka
# 10       85489184      M    20120101         West     Maharashtra
# 11       85438231      M    20120103         West     Maharashtra
# 12       74053888      F    20120102         West         Gujarat
# ...

# %%
DiffSet=CustomerData[CustomerData.duplicated(['Customer_ID'])]
DiffSet
# Out:
#       Customer_ID   Gender  First_Date First_region     First_state  \
# 9817    113918804        M    20120226         West         Gujarat
# 9818    113933467        F    20120226        South      Tamil Nadu
# 9819     41337621        F    20120228         West         Gujarat
# 9820      6896372        M    20120228         West     Maharashtra
# 9821    114142599        M    20120303         West         Gujarat
# 9822       586957        M    20120308        North   Uttar Pradesh
# 9823    114330400        M    20120307         West         Gujarat
# 9824    114731117  unknown    20120314         West         Gujarat
# 9825    114908563        F    20120318         West         Gujarat
# 9826       823086        M    20120316         West     Maharashtra
# 9827    114940492        F    20120317        North   Uttar Pradesh
# 9828     12605170        M    20120330        North   Uttar Pradesh
# 9829     50248089        F    20120330        South      Tamil Nadu
# ...
